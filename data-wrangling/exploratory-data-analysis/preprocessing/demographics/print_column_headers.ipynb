# %% [markdown]
# In total, the CSV files in 'raw-data/historical-elections/demographics' (the ones starting with 'Population_') have 12,919 columns.

# %%
import pandas as pd

path = '../../../raw-data/historical-elections/demographics/Population_'

# %%
filename = 'PersonsBySocioeconomyIndustry.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# maybe only get 'topledere' (total) and 'arbejdsløse' (total)
# Out:
# Population_PersonsBySocioeconomyIndustry.csv:
# ---
# Number of columns: 1277
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Socio-økonomisk status og brancher fordelt på afstemningsområder_01. Selvstændig og medhj._01. Landbrug skovbrug og fiskeri
# KV2009 - Socio-økonomisk status og brancher fordelt på afstemningsområder_01. Selvstændig og medhj._02. Industri råstofindvinding og forsyningsvirksomhed
# KV2009 - Socio-økonomisk status og brancher fordelt på afstemningsområder_01. Selvstændig og medhj._03. Bygge og anlæg
# KV2009 - Socio-økonomisk status og brancher fordelt på afstemningsområder_01. Selvstændig og medhj._04. Handel og transport mv.
# KV2009 - Socio-økonomisk status og brancher fordelt på afstemningsområder_01. Selvstændig og medhj._05. Information og kommunikation
# KV2009 - Socio-økonomisk status og brancher fordelt på afstemningsområder_01. Selvstændig og medhj._06. Finansiering og forsikring
# ...

# %%
filename = 'CrimeLegalRulings.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# let's not use this one
# Out:
# Population_CrimeLegalRulings.csv:
# ---
# Number of columns: 17
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Kriminalitet C. Retsafgørelser_1. Skyldig
# KV2009 - Kriminalitet C. Retsafgørelser_2. Ikke skyldig
# KV2013 - Kriminalitet C. Retsafgørelser_1. Skyldig
# KV2013 - Kriminalitet C. Retsafgørelser_2. Ikke skyldig
# KV2001 - Kriminalitet C. Retsafgørelser_1. Skyldig
# KV2001 - Kriminalitet C. Retsafgørelser_2. Ikke skyldig
# KV2005 - Kriminalitet C. Retsafgørelser_1. Skyldig
# KV2005 - Kriminalitet C. Retsafgørelser_2. Ikke skyldig
# KV2017 - Kriminalitet C. Retsafgørelser_1. Skyldig
# KV2017 - Kriminalitet C. Retsafgørelser_2. Ikke skyldig
# KV2021 - Kriminalitet C. Retsafgørelser_1. Skyldig
# KV2021 - Kriminalitet C. Retsafgørelser_2. Ikke skyldig

# %%
filename = 'PersonsByOccupationalStatusIndustry.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# something interesting here... 'topledere' e.g.
# Out:
# Population_PersonsByOccupationalStatusIndustry.csv:
# ---
# Number of columns: 665
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Personer efter stilling og erhverv (2000-2005)_01. Selvstændig og medhj.
# KV2009 - Personer efter stilling og erhverv (2000-2005)_01. Selvstændig og medhj._01. Landbrug
# KV2009 - Personer efter stilling og erhverv (2000-2005)_01. Selvstændig og medhj._02. Fremstilling
# KV2009 - Personer efter stilling og erhverv (2000-2005)_01. Selvstændig og medhj._03. Bygge- og anlæg
# KV2009 - Personer efter stilling og erhverv (2000-2005)_01. Selvstændig og medhj._04. Handel m.v
# KV2009 - Personer efter stilling og erhverv (2000-2005)_01. Selvstændig og medhj._05. Transport m.v.
# KV2009 - Personer efter stilling og erhverv (2000-2005)_01. Selvstændig og medhj._06. Undervisning
# KV2009 - Personer efter stilling og erhverv (2000-2005)_01. Selvstændig og medhj._07. Social
# ...

# %%
filename = 'PersonsByBenefitDurationAndAge.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# idea:
# maybe not get this
# Out:
# Population_PersonsByBenefitDurationAndAge.csv:
# ---
# Number of columns: 155
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Personer fordelt efter samlet ydelsesvarighed alder og afstemningsområde_18-29 år_0 - 3 mdr.
# KV2009 - Personer fordelt efter samlet ydelsesvarighed alder og afstemningsområde_18-29 år_3 - 6 mdr.
# KV2009 - Personer fordelt efter samlet ydelsesvarighed alder og afstemningsområde_18-29 år_6 - 9 mdr.
# KV2009 - Personer fordelt efter samlet ydelsesvarighed alder og afstemningsområde_18-29 år_9 - 12 mdr.
# KV2009 - Personer fordelt efter samlet ydelsesvarighed alder og afstemningsområde_18-29 år_Modtog ikke ydelser
# KV2009 - Personer fordelt efter samlet ydelsesvarighed alder og afstemningsområde_30-49 år_0 - 3 mdr.
# KV2009 - Personer fordelt efter samlet ydelsesvarighed alder og afstemningsområde_30-49 år_3 - 6 mdr.
# KV2009 - Personer fordelt efter samlet ydelsesvarighed alder og afstemningsområde_30-49 år_6 - 9 mdr.
# ...

# %%
filename = 'PersonsByBenefitType.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# idea:
# maybe only get 'antal personer i alt', 'kontanthjælp', 'folkepension', 'førtidspension' and 'modtager ikke ydelser'
# Out:
# Population_PersonsByBenefitType.csv:
# ---
# Number of columns: 77
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Personer efter forsørgelsestype_01. Arbejdsløshedsdagpenge
# KV2009 - Personer efter forsørgelsestype_02. Ledighedsydelse og Fleksjob
# KV2009 - Personer efter forsørgelsestype_03. Aktivering
# KV2009 - Personer efter forsørgelsestype_04. Sygedagpenge
# KV2009 - Personer efter forsørgelsestype_05. Kontanthjælp
# KV2009 - Personer efter forsørgelsestype_06. Revalidering
# KV2009 - Personer efter forsørgelsestype_07. Barselsdagpenge
# KV2009 - Personer efter forsørgelsestype_08. Førtidspension
# KV2009 - Personer efter forsørgelsestype_09. Efterløn
# KV2009 - Personer efter forsørgelsestype_10. Folkepension
# KV2009 - Personer efter forsørgelsestype_11. Modtager ikke ydelser
# KV2009 - Personer efter forsørgelsestype_12. Antal personer i alt
# KV2013 - Personer efter forsørgelsestype_01. Arbejdsløshedsdagpenge
# ...

# %%
filename = 'HousingByYearOfConstruction.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# idea:
# get old buildings (maybe before 1999) and new buildings, and people living in old and new buildings
# = 4 columns per election
# Out:
# Population_HousingByYearOfConstruction.csv:
# ---
# Number of columns: 185
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Opførelsesår_Antal boliger_1940-1959
# KV2009 - Opførelsesår_Antal boliger_1960-1969
# KV2009 - Opførelsesår_Antal boliger_1970-1979
# KV2009 - Opførelsesår_Antal boliger_1980-1989
# KV2009 - Opførelsesår_Antal boliger_1990-1999
# KV2009 - Opførelsesår_Antal boliger_2000-
# KV2009 - Opførelsesår_Antal boliger_Før 1940
# KV2009 - Opførelsesår_Antal personer_1940-1959
# KV2009 - Opførelsesår_Antal personer_1960-1969
# KV2009 - Opførelsesår_Antal personer_1970-1979
# KV2009 - Opførelsesår_Antal personer_1980-1989
# KV2009 - Opførelsesår_Antal personer_1990-1999
# KV2009 - Opførelsesår_Antal personer_2000-
# KV2009 - Opførelsesår_Antal personer_Før 1940
# KV2009 - Opførelsesår_Antal_boliger_1940-1959
# KV2009 - Opførelsesår_Antal_boliger_1960-1969
# KV2009 - Opførelsesår_Antal_boliger_1970-1979
# ...

# %%
filename = 'MembershipChurchOfDenmark.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# this could be interesting, right? only 2 columns per election
# Out:
# Population_MembershipChurchOfDenmark.csv:
# ---
# Number of columns: 17
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Medlemsskab af folkekirken fordelt på afstemningsområder_Ikke medlem af folkekirken
# KV2009 - Medlemsskab af folkekirken fordelt på afstemningsområder_Medlem af folkekirken
# KV2013 - Medlemsskab af folkekirken fordelt på afstemningsområder_Ikke medlem af folkekirken
# KV2013 - Medlemsskab af folkekirken fordelt på afstemningsområder_Medlem af folkekirken
# KV2001 - Medlemsskab af folkekirken fordelt på afstemningsområder_Ikke medlem af folkekirken
# KV2001 - Medlemsskab af folkekirken fordelt på afstemningsområder_Medlem af folkekirken
# KV2005 - Medlemsskab af folkekirken fordelt på afstemningsområder_Ikke medlem af folkekirken
# KV2005 - Medlemsskab af folkekirken fordelt på afstemningsområder_Medlem af folkekirken
# KV2017 - Medlemsskab af folkekirken fordelt på afstemningsområder_Ikke medlem af folkekirken
# ...

# %%
filename = 'CrimeConvictionsByOrigin.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# but what are 'indvandrere'???
# Out:
# Population_CrimeConvictionsByOrigin.csv:
# ---
# Number of columns: 23
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_1. Dansk oprindelse
# KV2009 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_2. Indvandrere
# KV2009 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_3. Efterkommere
# KV2013 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_1. Dansk oprindelse
# KV2013 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_2. Indvandrere
# KV2013 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_3. Efterkommere
# KV2001 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_1. Dansk oprindelse
# KV2001 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_2. Indvandrere
# KV2001 - Kriminalitet D. Strafferetslige afgørelser efter oprindelse_3. Efterkommere
# ...

# %%
filename = 'CrimeArrests.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# maybe this is the only interesting/most realistic crime data to include?
# Out:
# Population_CrimeArrests.csv:
# ---
# Number of columns: 11
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Kriminalitet B. Anholdelser_Antal anholdelser
# KV2013 - Kriminalitet B. Anholdelser_Antal anholdelser
# KV2001 - Kriminalitet B. Anholdelser_Antal anholdelser
# KV2005 - Kriminalitet B. Anholdelser_Antal anholdelser
# KV2017 - Kriminalitet B. Anholdelser_Antal anholdelser
# KV2021 - Kriminalitet B. Anholdelser_Antal anholdelser

# %%
filename = 'ImmigrantsDescendantsByCountryOfOrigin.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)
# Out:
# Population_ImmigrantsDescendantsByCountryOfOrigin.csv:
# ---
# Number of columns: 4421
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Indvandrere og efterkommere fordelt efter oprindelsesland_Kvinder 0-4 år
# KV2009 - Indvandrere og efterkommere fordelt efter oprindelsesland_Kvinder 0-4 år_02. Nordiske lande
# KV2009 - Indvandrere og efterkommere fordelt efter oprindelsesland_Kvinder 0-4 år_02.Nordiske lande
# KV2009 - Indvandrere og efterkommere fordelt efter oprindelsesland_Kvinder 0-4 år_03. Tyrkiet
# KV2009 - Indvandrere og efterkommere fordelt efter oprindelsesland_Kvinder 0-4 år_03.Tyrkiet
# KV2009 - Indvandrere og efterkommere fordelt efter oprindelsesland_Kvinder 0-4 år_04. Tidligere Jugoslavien
# KV2009 - Indvandrere og efterkommere fordelt efter oprindelsesland_Kvinder 0-4 år_04.Tidligere Jugoslavien
# KV2009 - Indvandrere og efterkommere fordelt efter oprindelsesland_Kvinder 0-4 år_05. Gamle EU-lande
# ...

# %%
filename = 'HighestCompletedEducationByAge.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# maybe we can ignore ages and just get the 'total' in each education level category?
# although that will skew the perspective in polling areas with a lot of people younger than 25 years.
# maybe we can ignore ignore ages get the 'total' in each education level category for people 25 years and older?
# Out:
# Population_HighestCompletedEducationByAge.csv:
# ---
# Number of columns: 701
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år_01.Grundskole
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år_02.Almengymnasial
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år_03.Erhvervsgymnaisal
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år_04.Erhvervsfaglig
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år_05.Kort videregående
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år_06.Mellemlang videregående
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år_07.Lang videregående
# KV2009 - Højst fuldførte erhvervsuddannelse og aldersgrupper_18-19 år_08.Uoplyst
# ...

# %%
filename = 'HouseholdIncomes.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# Maybe just get:
# Under 100.000 kr.
# 100.000 - 149.999 kr
# 150.000 - 199.999 kr.
# 200.000 - 299.999 kr.
# 300.000 - 399.999 kr.
# 400.000 - 499.999 kr.
# 500.000 - 749.999 kr.
# 750.000 kr.
# Antal husstande i alt

# OR JUST:
# 50%-percentil for husstandsindkomst
# (and maybe: Bruttoindkomst for de 20% der tjener mest)
# Out:
# Population_HouseholdIncomes.csv:
# ---
# Number of columns: 107
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_100.000 - 149.999 kr
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_150.000 - 199.999 kr.
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_200.000 - 299.999 kr.
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_300.000 - 399.999 kr.
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_400.000 - 499.999 kr.
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_50%-percentil for husstandsindkomst
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_500.000 - 749.999 kr.
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_750.000 kr.-
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_80%-percentil for husstandsindkomst
# KV2009 - Husstandsindkomster fordelt på afstemningsområder_Antal husstande i alt
# ...

# %%
filename = 'HouseholdsCarOwnership.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# only 3 columns per election
# but could also be a single column: cars (and then yes or no (binary) or 0, 1 or 2 (where 2 means 2 or more)
# Out:
# Population_HouseholdsCarOwnership.csv:
# ---
# Number of columns: 23
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Husstande efter bilrådighed_1. Husstande uden bil
# KV2009 - Husstande efter bilrådighed_2. Husstande med 1 bil
# KV2009 - Husstande efter bilrådighed_3. Husstande med 2 eller flere biler
# KV2013 - Husstande efter bilrådighed_1. Husstande uden bil
# KV2013 - Husstande efter bilrådighed_2. Husstande med 1 bil
# KV2013 - Husstande efter bilrådighed_3. Husstande med 2 eller flere biler
# KV2001 - Husstande efter bilrådighed_1. Husstande uden bil
# KV2001 - Husstande efter bilrådighed_2. Husstande med 1 bil
# KV2001 - Husstande efter bilrådighed_3. Husstande med 2 eller flere biler
# KV2005 - Husstande efter bilrådighed_1. Husstande uden bil
# KV2005 - Husstande efter bilrådighed_2. Husstande med 1 bil
# KV2005 - Husstande efter bilrådighed_3. Husstande med 2 eller flere biler
# KV2017 - Husstande efter bilrådighed_1. Husstande uden bil
# ...

# %%
filename = 'HousingType.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)
# Out:
# Population_HousingType.csv:
# ---
# Number of columns: 173
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Boligtype_Antal boliger
# KV2009 - Boligtype_Antal boliger_01. Stuehuse og parcelhuse
# KV2009 - Boligtype_Antal boliger_02. Række- og kædehuse
# KV2009 - Boligtype_Antal boliger_03. Flerfamiliehuse
# KV2009 - Boligtype_Antal boliger_04. Kollegier
# KV2009 - Boligtype_Antal boliger_05. Sommerhuse
# KV2009 - Boligtype_Antal boliger_06. Øvrige boliger
# KV2009 - Boligtype_Antal boliger_07. Ingen BBR-oplysninger
# KV2009 - Boligtype_Antal personer
# KV2009 - Boligtype_Antal personer_01. Stuehuse og parcelhuse
# KV2009 - Boligtype_Antal personer_02. Række- og kædehuse
# KV2009 - Boligtype_Antal personer_03. Flerfamiliehuse
# KV2009 - Boligtype_Antal personer_04. Kollegier
# KV2009 - Boligtype_Antal personer_05. Sommerhuse
# KV2009 - Boligtype_Antal personer_06. Øvrige boliger
# KV2009 - Boligtype_Antal personer_07. Ingen BBR-oplysninger
# ...

# %%
filename = 'HousingTenure.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# this is very interesting!!! especially for this year's election debates
# Out:
# Population_HousingTenure.csv:
# ---
# Number of columns: 173
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Ejerforhold_Antal boliger
# KV2009 - Ejerforhold_Antal boliger_01. Ejerbolig
# KV2009 - Ejerforhold_Antal boliger_02. Andelsbolig
# KV2009 - Ejerforhold_Antal boliger_03. Almennyttig bolig
# KV2009 - Ejerforhold_Antal boliger_04. Lejer i offentligt ejet
# KV2009 - Ejerforhold_Antal boliger_05. Privat lejerbolig
# KV2009 - Ejerforhold_Antal boliger_06. Øvrige beboede boliger
# KV2009 - Ejerforhold_Antal boliger_07. Ingen BBR-oplysninger
# KV2009 - Ejerforhold_Antal personer
# KV2009 - Ejerforhold_Antal personer_01. Ejerbolig
# KV2009 - Ejerforhold_Antal personer_02. Andelsbolig
# KV2009 - Ejerforhold_Antal personer_03. Almennyttig bolig
# KV2009 - Ejerforhold_Antal personer_04. Lejer i offentligt ejet
# KV2009 - Ejerforhold_Antal personer_05. Privat lejerbolig
# KV2009 - Ejerforhold_Antal personer_06. Øvrige beboede boliger
# ...

# %%
filename = 'PersonsByCitizenshipSexAge.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# if we want age distribution for different polling areas, we should get some of this.
# Maybe we don't need citizenship? So only get the totals within each sex/age group
# Out:
# Population_PersonsByCitizenshipSexAge.csv:
# ---
# Number of columns: 4805
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Antal personer opgjort efter statsborgerskab køn og aldersgrupper_Kvinder 0-4 år
# KV2009 - Antal personer opgjort efter statsborgerskab køn og aldersgrupper_Kvinder 0-4 år_01. Danmark
# KV2009 - Antal personer opgjort efter statsborgerskab køn og aldersgrupper_Kvinder 0-4 år_01.Danmark
# KV2009 - Antal personer opgjort efter statsborgerskab køn og aldersgrupper_Kvinder 0-4 år_02. Nordiske lande
# KV2009 - Antal personer opgjort efter statsborgerskab køn og aldersgrupper_Kvinder 0-4 år_02.Nordiske lande
# KV2009 - Antal personer opgjort efter statsborgerskab køn og aldersgrupper_Kvinder 0-4 år_03. Tyrkiet
# KV2009 - Antal personer opgjort efter statsborgerskab køn og aldersgrupper_Kvinder 0-4 år_03.Tyrkiet
# KV2009 - Antal personer opgjort efter statsborgerskab køn og aldersgrupper_Kvinder 0-4 år_04. Tidligere Jugoslavien
# ...

# %%
filename = 'HousingSize.csv'
df = pd.read_csv(path + filename, delimiter=';', nrows=0) # only get headers
column_headers = df.columns.tolist()
print(f'Population_{filename}:')
print('---')
print(f'Number of columns: {len(column_headers)}')
print('---')
for header in column_headers:
    print(header)

# maybe we don't need this
# Out:
# Population_HousingSize.csv:
# ---
# Number of columns: 89
# ---
# Gruppe
# ValgstedId
# KredsNr
# StorKredsNr
# LandsdelsNr
# KV2009 - Boliger og personer efter boligstørrelse_01. Antal boliger_0-39 m2
# KV2009 - Boliger og personer efter boligstørrelse_02. Antal boliger_40-79 m2
# KV2009 - Boliger og personer efter boligstørrelse_03.Antal boliger_80-119 m2
# KV2009 - Boliger og personer efter boligstørrelse_04. Antal boliger_120-159 m2
# KV2009 - Boliger og personer efter boligstørrelse_05. Antal boliger_160-199 m2
# KV2009 - Boliger og personer efter boligstørrelse_06. Antal boliger_200+ m2
# KV2009 - Boliger og personer efter boligstørrelse_07. Antal boliger_Uoplyst areal
# KV2009 - Boliger og personer efter boligstørrelse_08. Antal personer_0-39 m2
# KV2009 - Boliger og personer efter boligstørrelse_09. Antal personer_40-79 m2
# KV2009 - Boliger og personer efter boligstørrelse_10. Antal personer_80-119 m2
# ...
